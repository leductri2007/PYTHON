# %%
from collections import Counter
a=(map(int,input().split()))
print(list(dict(Counter(a)).items()))
# Out:
# [(1, 2), (2, 3), (3, 1)]

# %%
a=list(map(int,input().split()))
b=list(map(int,input().split()))
s1=set(a)
s2=set(b)
for x in s1:
    if x not in s2:
        print(x,end=" ")
# Out:
# 2
